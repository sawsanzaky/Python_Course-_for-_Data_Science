# %% [markdown]
# # Introduction to Python

# %% [markdown]
# # Course Description

# %% [markdown]
# Begin your journey into Data Science!
# Even if you've never written a line of code in your life,
# you'll be able to follow this course and witness the power of Python to perform Data Science.
# You'll use data to solve the mystery of Bayes, the kidnapped Golden Retriever,
# and along the way you'll become familiar with basic Python syntax
# and popular Data Science modules like Matplotlib (for charts and graphs) and pandas (for tabular data).

# %% [markdown]
# ![PythonApplications-Python-Career-Opurtunity-Edureka-2.jpg](attachment:PythonApplications-Python-Career-Opurtunity-Edureka-2.jpg)

# %% [markdown]
# # why python

# %% [markdown]
# ![ak.jpg](attachment:ak.jpg)

# %% [markdown]
# # python Application

# %% [markdown]
# ![main-qimg-4643e864bb7a3834e092393a73d25c2b.png](attachment:main-qimg-4643e864bb7a3834e092393a73d25c2b.png)

# %% [markdown]
# # Syllabus

# %% [raw]
# 1.Execute Python Syntax
# 2.Python Comments
# 3.Creating Variables
# 4.Python Data Types
# 5.Python Casting
# 6.Python Strings
# 7.Python Booleans
# 8.Python Operators
# 9.Python Lists
# 10.Python Tuples
# 11.Python Sets
# 12.Python Dictionaries
# 13.Python If ... Else
# 14.Python Loops
#        . For Loop
#        .while Loop
# 15.Python Arrays
# 16.Python Functions

# %% [markdown]
# # 1.Execute Python Syntax

# %%
# mean print statment 
print('Hello Haneen in AI World ')

print(" نبنملقلقلصقخحلصقتخحصقلنصقهثقخقهلقت89681146488")
# Out:
# Hello Haneen in AI World
#  نبنملقلقلصقخحلصقتخحصقلنصقهثقخقهلقت89681146488

# %%
   
    print('Hello Haneen in AI World ')
# Out:
# Hello Haneen in AI World

# %%
# Python Indentation .... Error Handling 
x=4
if x > 10 :
    print("..block..")
print(" your number greater than 10")
# Out:
#  your number greater than 10

# %% [markdown]
# # 2.Python Comments

# %% [raw]
# Comments starts with a #
# (triple quotes) in your code
#
# Comments can be used to explain Python code.
#
# Comments can be used to make the code more readable.
#
# Comments can be used to prevent execution when testing code.

# %%
print('Hello Haneen in AI World ') #This is a comment
# Out:
# Hello Haneen in AI World

# %%
#use to mute code 
#print("sawsan")
print(" Data Science World")
# Out:
#  Data Science World

# %%
"""
This is a comment
written in
more than just one line
"""
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# # 3.Creating Variables

# %% [markdown]
#  Variables are containers for storing data values.

# %%
x = 5
y = "Haneen"
print(x)
print(y)
# Out:
# 5
# Haneen

# %% [markdown]
# # 4.Python Data Types

# %% [markdown]
# In programming, data type is an important concept.
#
# Variables can store data of different types, and different types can do different things.
#
# Python has the following data types built-in by default, in these categories:

# %% [markdown]
# ![2022-06-22%20%282%29.png](attachment:2022-06-22%20%282%29.png)

# %%
x = 4       # x is of type int
x = "Haneen" # x is now of type str
print(x)
# Out:
# Haneen

# %% [markdown]
# get the data type of any object by using the type() function:

# %%
x = 5
print(type(x))
# Out:
# <class 'int'>

# %%
x = ["apple", "banana", "cherry"]
print(type(x ))
# Out:
# <class 'list'>

# %%
x = {"name" : "John", "age" : 36}
print(type(x ))

# %%
x = int(input(" please enter your number : "))
print(type(x))
y =5*x

print(y)
# Out:
#  please enter your number : 5
# <class 'int'>
# 25

# %% [markdown]
# # 5.Python Casting

# %% [markdown]
# There may be times when you want to specify a type on to a variable.
# This can be done with casting. Python is an object-orientated language,
# and as such it uses classes to define data types, including its primitive types.

# %% [raw]
# 1-int() - constructs an integer number from an integer literal, a float literal (by removing all decimals), or a string literal (providing the string represents a whole number)
# 2-float() - constructs a float number from an integer literal, a float literal or a string literal (providing the string represents a float or an integer)
# 3-str() - constructs a string from a wide variety of data types, including strings, integer literals and float literals

# %%
x = str(3)    # x will be '3'
y = int(3)    # y will be 3
z = float(3)  # z will be 3.0

# %%
age = 14
name = "Haneen" 
#print ( "Name : " + name )
#print ( "Name : " , name )
#print ( "Name : " , name , " Age : " , age)
#print( name + str(age))
print( name + str(age))
# Out:
# Haneen14

# %% [markdown]
# # 6.Python Strings

# %% [markdown]
# Strings in python are surrounded by either single quotation marks, or double quotation marks.

# %%
print("Haneen")
print('Haneen')
# Out:
# Haneen
# Haneen

# %%
a = 'Hane        en '
print(a[0]) # Slicing Strings
print(a[-1])
# Out:
# H

# %%
a='sawsan,haneen'
print(a[1])
# Out:
# a

# %%
for x in "Haneen":
  print(x)
# Out:
# H
# a
# n
# e
# e
# n

# %%
a = "Haneen"
#print(5*a)
for x in a : print("your name is :  " , a)
# Out:
# your name is :   Haneen
# your name is :   Haneen
# your name is :   Haneen
# your name is :   Haneen
# your name is :   Haneen
# your name is :   Haneen

# %% [markdown]
# To get the length of a string, use the len() function

# %%
a = "Haneen World!"
x="sawsan"
print(len(x))
print(len(a))
# Out:
# 6
# 13

# %%
#Check String
txt = "The best things in life are free!"
print("free" in txt)
# Out:
# True

# %%
x = " haneen ahmed"
print( "Haneen" in x )
# Out:
# False

# %% [markdown]
# # 7.Python Booleans

# %% [markdown]
# In programming you often need to know if an expression is True or False.
#
# You can evaluate any expression in Python, and get one of two answers, True or False.
#
# When you compare two values.

# %%
print(10 > 9)
print(10 == 9)
print(10 != 9)
print(10 >= 9)
print(10 <= 9)
print(10 < 9)
# Out:
# True
# False
# True
# True
# False
# False

# %%
x = "Haneen"
y = 15

print(bool(x))
print(bool(y))
# Out:
# True
# True

# %% [markdown]
# # 8.Python Operators

# %% [markdown]
# Operators are used to perform operations on variables and values.

# %% [markdown]
# Python divides the operators in the following groups:
#
# Arithmetic operators
# Assignment operators
# Comparison operators
# Logical operators
# Identity operators
# Membership operators
# Bitwise operators

# %% [markdown]
# Arithmetic operators

# %% [markdown]
# ![2022-06-22%20%288%29.png](attachment:2022-06-22%20%288%29.png)

# %% [markdown]
# ![2022-06-22%20%289%29.png](attachment:2022-06-22%20%289%29.png)

# %% [markdown]
# ![2022-06-22%20%2810%29.png](attachment:2022-06-22%20%2810%29.png)

# %% [markdown]
# ![2022-06-22%20%2811%29.png](attachment:2022-06-22%20%2811%29.png)

# %% [markdown]
# ![2022-06-22%20%2812%29.png](attachment:2022-06-22%20%2812%29.png)

# %% [markdown]
# ![2022-06-22%20%288%29.png](attachment:2022-06-22%20%288%29.png)

# %% [markdown]
# # List is a collection which is ordered and changeable. Allows duplicate members.
# Tuple is a collection which is ordered and unchangeable. Allows duplicate members.
# Set is a collection which is unordered, unchangeable*, and unindexed. No duplicate members.
# Dictionary is a collection which is ordered** and changeable. No duplicate members.

# %% [markdown]
# # 9.Python Lists

# %% [markdown]
# Lists are used to store multiple items in a single variable.
#
# Lists are one of 4 built-in data types in Python used to store collections of data, the other 3 are Tuple, Set,
# and Dictionary, all with different qualities and usage.

# %%
fruits = ["apple", "banana", "cherry", "apple", "cherry"]
a = ["sawsan", "haneen","eman"]
print(a)
print(fruits)
# Out:
# ['sawsan', 'haneen', 'eman']
# ['apple', 'banana', 'cherry', 'apple', 'cherry']

# %%
print(len(fruits))
# Out:
# 5

# %%
print(type(fruits))
# Out:
# <class 'list'>

# %%
print(fruits[0])
# Out:
# apple

# %%
fruits = ["apple", "banana", "cherry", "apple", "cherry"]
for x in fruits:
    print(  x , " is a fruit")
# Out:
# apple  is a fruit
# banana  is a fruit
# cherry  is a fruit
# apple  is a fruit
# cherry  is a fruit

# %%
list1 = ["abc", 34, True, 40, "male",["sawsan", "haneen"]]
print(type(list1[-3]))
list1 = ["sawsan"] 
print(list1+list1)
# Out:
# <class 'int'>

# %%
list1 = ["sawsan"] 
print(list1+list1)
# Out:
# ['sawsan', 'sawsan']

# %% [markdown]
# # 10.Python Tuples

# %% [markdown]
# A tuple is a collection which is ordered and unchangeable
# Tuples are used to store multiple items in a single variable.
# list []
# tuple  ()
# dic {}

# %%
mytuple = ("apple", "banana", "cherry","apple", "banana", "cherry")
len(mytuple )
print(mytuple[0])
# Out:
# apple

# %%
for x in mytuple:
    print(x)
# Out:
# apple
# banana
# cherry
# apple
# banana
# cherry

# %%
apple

# %%
type(mytuple)
# Out:
# tuple

# %% [markdown]
# # 11.Python Sets

# %% [markdown]
# Sets are used to store multiple items in a single variable.
#
# Set is one of 4 built-in data types in Python used to store collections of data,
# the other 3 are List, Tuple, and Dictionary, all with different qualities and usage.

# %%
fruits = {"apple", "banana", "cherry","banana","banana"}
print(fruits)
# Out:
# {'banana', 'cherry', 'apple'}

# %%
len(fruits)
# Out:
# 3

# %%
set

# %% [markdown]
# # 12.Python Dictionaries

# %% [markdown]
# Dictionaries are used to store data values in key:value pairs.
#
# A dictionary is a collection which is ordered*, changeable and do not allow duplicates.

# %%
data = {
  "haneen": 14,
  "sawsan": 28,
  "year":2022,
    "eduation":"AI",
    "SPORT":["swimming","reading","watching ",14]
}

# %%
data .... haneen .... name  age  sisters year eduction  username

# %%
data1 =["sawsan","haneen"] 
data2 = [28,14]

# %%
print(" our year is : ",data[ "year"])
# Out:
#  our year is :  2022

# %%
print("sport of haneen : ", data["SPORT"])
# Out:
# sport of haneen :  ['swimming', 'reading', 'watching ', 14]

# %%
print(data)
# Out:
# {'haneen': 14, 'sawsan': 28, 'year': 2022}

# %%
print(data["haneen"])
# Out:
# 14

# %%
data = {
  "haneen": 14,
  "sawsan": 28,
  "year": 1964,
    "year":14
}

# %%
data
# Out:
# {'haneen': 14, 'sawsan': 28, 'year': 14}

# %%
thisdict = {
  "brand": "Ford",
  "electric": False,
  "year": 1964,
  "colors": ["red", "white", "blue"]
}

# %%
print(type(thisdict))
# Out:
# <class 'dict'>

# %%
data = { "eduation": {key : value }}

# %%
 #H.W
Dictionary ..... define yourself
name age sisters with there name   material education nationality

# %% [markdown]
# # session ...... 2

# %% [markdown]
# # 13.Python If ... Else

# %% [markdown]
# Python Conditions and If statements
# Python supports the usual logical conditions from mathematics:
#
# Equals: a == b
# Not Equals: a != b
# Less than: a < b
# Less than or equal to: a <= b
# Greater than: a > b
# Greater than or equal to: a >= b

# %%
a = 33
b = 200
if b > a:
  print("b is greater than a")
# Out:
# b is greater than a

# %%
a = 33
b = 33
if b > a:
  print("b is greater than a")
elif a == b:
  print("a and b are equal")
# Out:
# a and b are equal

# %%
if a > b: print("a is greater than b")

# %%
a = 200
b = 33
c = 500
if a > b and c > a:
  print("Both conditions are True")
# Out:
# Both conditions are True

# %% [markdown]
# # 14.Python Loops

# %% [markdown]
# A for loop is used for iterating over a sequence (that is either a list, a tuple, a dictionary, a set, or a string).

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
for x in "banana":
  print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  print(x)
  if x == "banana":
    break
# Out:
# apple
# banana

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  if x == "banana":
    break
  print(x)
# Out:
# apple

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  if x == "banana":
    continue
  print(x)
# Out:
# apple
# cherry

# %%
for x in range(6):
  print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for x in range(2, 6):
  print(x)
# Out:
# 2
# 3
# 4
# 5

# %%
for x in range(2, 30, 3):
  print(x)
# Out:
# 2
# 5
# 8
# 11
# 14
# 17
# 20
# 23
# 26
# 29

# %%
for x in range(6):
  print(x)
else:
  print("Finally finished!")
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# Finally finished!

# %% [markdown]
#  while loop we can execute a set of statements as long as a condition is true.

# %%
i = 1
while i < 6:
  print(i)
  i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i = 1
while i < 6:
  print(i)
  if i == 3:
    break
  i += 1
# Out:
# 1
# 2
# 3

# %%
i = 0
while i < 6:
  i += 1
  if i == 3:
    continue
  print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %% [markdown]
# # 15.Array

# %% [markdown]
# Arrays are used to store multiple values in one single variable:

# %%
cars = ["Ford", "Volvo", "BMW"]

# %% [markdown]
# # 16.Python Functions

# %% [markdown]
# A function is a block of code which only runs when it is called.
#
# You can pass data, known as parameters, into a function.
#
# A function can return data as a result

# %%
def my_function():
  print("Hello from a function")

my_function()
# Out:
# Hello from a function

# %%
def my_function(fname):
  print(fname + " Refsnes")

my_function("Emil")
my_function("Tobias")
my_function("Linus")
# Out:
# Emil Refsnes
# Tobias Refsnes
# Linus Refsnes

# %%
def my_function(fname, lname):
  print(fname + " " + lname)

my_function("Emil", "Refsnes")
# Out:
# Emil Refsnes
